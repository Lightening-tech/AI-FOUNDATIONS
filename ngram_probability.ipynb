# %%
from datetime import datetime

print(f"Today is {datetime.today():%A}.")
# Out:
# Today is Wednesday.

# %%
# %%capture
# Install the custom package for this course if possible.
try:
    # %pip install --quiet "git+https://github.com/google-deepmind/ai-foundations.git@main"
except Exception:
    pass

# Packages used.
# For randomly picking elements from a probability distribution.
import random

# Custom functions for providing feedback on your solutions.
try:
    from ai_foundations.feedback.course_1 import probabilities
except ModuleNotFoundError:
    class _ProbabilitiesPlaceholder:
        @staticmethod
        def test_probabilities(candidate_words, probs):
            if len(candidate_words) != len(probs):
                raise ValueError("The number of candidate words and probabilities must match.")
            if any(p < 0 or p > 1 for p in probs):
                raise ValueError("Probabilities must be between 0 and 1.")
            if abs(sum(probs) - 1.0) > 1e-9:
                raise ValueError("Probabilities must sum to 1.")
            print("Probabilities look valid.")

    probabilities = _ProbabilitiesPlaceholder()

# %%
your_mental_model = [0.99, 0.001, 0.009]

# %%
candidate_words = ["star", "beef", "bootle"]

# The probabilities for each word are defined in the following list.
your_mental_model = [0.99, 0.001, 0.009]

# This function runs several checks to verify that your_mental_model defines
# a proper probability distribution.
probabilities.test_probabilities(candidate_words, your_mental_model)
# Out:
# Probabilities look valid.

# %%
chosen_word = random.choices(candidate_words, weights=your_mental_model)

print(f"Twinkle twinkle little {chosen_word[0]}.")
# Out:
# Twinkle twinkle little star.

# %%
candidate_words = [
    "food",
    "snacks",
    "leftovers",
    "her",
    "for",
    "water",
    "photosyhthesis",
    "pyramid",
]

# Enter the probabilities for the candidates words to follow the 
# prompt "Jide was hungry so she went looking for"
your_mental_model = [0.2, 0.346, 0.2, 0.09, 0.001, 0.16, 0.002, 0.001]

#This function runs several checks to verify that your_mental_model defines
# a proper probability distribution.
probabilities.test_probabilities(candidate_words, your_mental_model)
# Out:
# Probabilities look valid.

# %%
chosen_word = random.choices(candidate_words, weights=your_mental_model)

print(f"Jide was hungry so she went looking for {chosen_word[0]} ...")
# Out:
# Jide was hungry so she went looking for snacks ...

# %%
candidate_words = [
    "food",
    "snacks",
    "leftovers",
    "her",
    "for",
    "water",
    "photosyhthesis",
    "pyramid",
]

# Enter the probabilities for the candidates words to follow the 
# prompt "Jide was hungry 5so she went looking for"
your_mental_model = [0.05, 0.046, 0.09, 0.05, 0.001, 0.76, 0.002, 0.001]

#This function runs several checks to verify that your_mental_model defines
# a proper probability distribution.
probabilities.test_probabilities(candidate_words, your_mental_model)
# Out:
# Probabilities look valid.

# %%
chosen_word = random.choices(candidate_words, weights=your_mental_model)

print(f"Jide was hungry so she went looking for {chosen_word[0]} ...")
# Out:
# Jide was hungry so she went looking for water ...
